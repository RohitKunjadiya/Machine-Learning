# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -2.789472  1.028508 -1.346117  0.153835  0.249945       1
# 1  0.285878  2.514583  2.577996 -1.678893  2.041955       1
# 2 -2.290529 -0.569767  1.114590  0.494620  0.478435       0
# 3 -1.698791 -1.138188  1.748022  0.881466  0.600943       0
# 4 -1.906694  1.371863 -0.793848 -0.503543  0.970160       1

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
bag.estimators_
# Out:
# [DecisionTreeClassifier(random_state=95819725),
#  DecisionTreeClassifier(random_state=490678473),
#  DecisionTreeClassifier(random_state=1542236029),
#  DecisionTreeClassifier(random_state=125358934),
#  DecisionTreeClassifier(random_state=789095496),
#  DecisionTreeClassifier(random_state=1170284407),
#  DecisionTreeClassifier(random_state=1719091434),
#  DecisionTreeClassifier(random_state=1210398767),
#  DecisionTreeClassifier(random_state=741410094),
#  DecisionTreeClassifier(random_state=1813865388)]

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier()

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier()

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1682654380),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1919543945),
#  DecisionTreeClassifier(max_features='sqrt', random_state=944737107),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1400459308),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1524973233),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1118731557),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1292583666),
#  DecisionTreeClassifier(max_features='sqrt', random_state=352923373),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2093950781),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1795340046),
#  DecisionTreeClassifier(max_features='sqrt', random_state=403360168),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2006505060),
#  DecisionTreeClassifier(max_features='sqrt', random_state=889058656),
#  DecisionTreeClassifier(max_features='sqrt', random_state=822460924),
#  DecisionTreeClassifier(max_features='sqrt', random_state=929757156),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1765377609),
#  DecisionTreeClassifier(max_features='sqrt', random_state=28829396),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1064184013),
#  DecisionTreeClassifier(max_features='sqrt', random_state=60885281),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1761056898),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1722238712),
#  DecisionTreeClassifier(max_features='sqrt', random_state=293652749),
#  DecisionTreeClassifier(max_features='sqrt', random_state=481625777),
#  DecisionTreeClassifier(max_features='sqrt', random_state=304967647),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1250686438),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1131555094),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1965085435),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1780820415),
#  DecisionTreeClassifier(max_features='sqrt', random_state=391964576),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1154304362),
#  DecisionTreeClassifier(max_features='sqrt', random_state=635010171),
#  DecisionTreeClassifier(max_features='sqrt', random_state=234382381),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2060430300),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1760570533),
#  DecisionTreeClassifier(max_features='sqrt', random_state=693130547),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1483991218),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1489180193),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1856189635),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1568590578),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1275054404),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1465500249),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1800285202),
#  DecisionTreeClassifier(max_features='sqrt', random_state=272553001),
#  DecisionTreeClassifier(max_features='sqrt', random_state=276057772),
#  DecisionTreeClassifier(max_features='sqrt', random_state=962689316),
#  DecisionTreeClassifier(max_features='sqrt', random_state=237747569),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1826132564),
#  DecisionTreeClassifier(max_features='sqrt', random_state=478196637),
#  DecisionTreeClassifier(max_features='sqrt', random_state=867713393),
#  DecisionTreeClassifier(max_features='sqrt', random_state=678392816),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1758668332),
#  DecisionTreeClassifier(max_features='sqrt', random_state=277793360),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1368774949),
#  DecisionTreeClassifier(max_features='sqrt', random_state=111492585),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1323481574),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1301357963),
#  DecisionTreeClassifier(max_features='sqrt', random_state=430989373),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1545609923),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1384405961),
#  DecisionTreeClassifier(max_features='sqrt', random_state=638296129),
#  DecisionTreeClassifier(max_features='sqrt', random_state=243295188),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1508651413),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1758193722),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1892193276),
#  DecisionTreeClassifier(max_features='sqrt', random_state=475867781),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1213711020),
#  DecisionTreeClassifier(max_features='sqrt', random_state=58781419),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1597669141),
#  DecisionTreeClassifier(max_features='sqrt', random_state=242182899),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1674498626),
#  DecisionTreeClassifier(max_features='sqrt', random_state=276810094),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1425677570),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1668979038),
#  DecisionTreeClassifier(max_features='sqrt', random_state=704478920),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1368936280),
#  DecisionTreeClassifier(max_features='sqrt', random_state=71469105),
#  DecisionTreeClassifier(max_features='sqrt', random_state=546865697),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1708515206),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1214379877),
#  DecisionTreeClassifier(max_features='sqrt', random_state=227281054),
#  DecisionTreeClassifier(max_features='sqrt', random_state=816201428),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1301748133),
#  DecisionTreeClassifier(max_features='sqrt', random_state=330696127),
#  DecisionTreeClassifier(max_features='sqrt', random_state=68057494),
#  DecisionTreeClassifier(max_features='sqrt', random_state=224885534),
#  DecisionTreeClassifier(max_features='sqrt', random_state=182974516),
#  DecisionTreeClassifier(max_features='sqrt', random_state=481381407),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2001869052),
#  DecisionTreeClassifier(max_features='sqrt', random_state=75979612),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1605774229),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2137131184),
#  DecisionTreeClassifier(max_features='sqrt', random_state=379897311),
#  DecisionTreeClassifier(max_features='sqrt', random_state=19217990),
#  DecisionTreeClassifier(max_features='sqrt', random_state=965263083),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1613487839),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1567752488),
#  DecisionTreeClassifier(max_features='sqrt', random_state=337978175),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1801447104),
#  DecisionTreeClassifier(max_features='sqrt', random_state=557904156),
#  DecisionTreeClassifier(max_features='sqrt', random_state=702339300)]

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[50])
plt.show()
