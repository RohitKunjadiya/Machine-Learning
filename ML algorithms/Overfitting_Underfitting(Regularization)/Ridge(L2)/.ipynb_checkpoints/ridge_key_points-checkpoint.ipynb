# %% [markdown]
# # 1. How are co-efficients get affected?

# %%
from sklearn.datasets import load_diabetes

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data = load_diabetes()

df = pd.DataFrame(data.data , columns = data.feature_names)
df['target'] = data.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.shape
# Out:
# (442, 11)

# %%
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %%
coef = []
r2_sc = []

for i in [0,10,100,1000]:
    r = Ridge(alpha=i)    
    r.fit(X_train,y_train)
    coef.append(r.coef_.tolist())
    y_pred = r.predict(X_test)
    r2_sc.append(r2_score(y_test,y_pred))
print(coef[0])
print(r2_sc)
# Out:
# [37.90402135007498, -241.96436231274183, 542.4287585162862, 347.7038439138571, -931.488845883658, 518.0622769834458, 163.41998299137592, 275.3179015786727, 736.1988589047384, 48.67065743196369]
# [0.45260276297191826, 0.161225867509881, 0.012171803489062438, -0.009452910647574031]

# %%
plt.figure(figsize=(14,9))
plt.subplot(221)
plt.bar(data.feature_names,coef[0])
plt.title('Alpha = 0 ,r2_score = {}'.format(round(r2_sc[0],2)))

plt.subplot(222)
plt.bar(data.feature_names,coef[1])
plt.title('Alpha = 10 ,r2_score = {}'.format(round(r2_sc[1],2)))

plt.subplot(223)
plt.bar(data.feature_names,coef[2])
plt.title('Alpha = 100 ,r2_score = {}'.format(round(r2_sc[2],2)))

plt.subplot(224)
plt.bar(data.feature_names,coef[3])
plt.title('Alpha = 1000 ,r2_score = {}'.format(round(r2_sc[3],2)))

plt.show()

# %% [markdown]
# #  2. Higher coefficients are affected more

# %%
alpha = [0,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]

coefs = []

for i in alpha:
    r = Ridge(i)
    r.fit(X_train,y_train)
    coefs.append(r.coef_.tolist())
    
input = np.array(coefs)

coef_df = pd.DataFrame(input,columns=data.feature_names)
coef_df['alpha'] = alpha
coef_df.set_index('alpha')
# Out:
#                   age         sex         bmi          bp          s1  \
# alpha
# 0.0000      37.904021 -241.964362  542.428759  347.703844 -931.488846
# 0.0001      37.968967 -241.900460  542.593504  347.604088 -919.863924
# 0.0010      38.483505 -241.351795  543.835179  346.782831 -827.701995
# 0.0100      40.693422 -237.008020  546.161792  341.809317 -430.146300
# 0.1000      42.855670 -205.494319  505.089033  317.093205 -108.500262
# 1.0000      45.367377  -76.666086  291.338832  198.995817   -0.530310
# 10.0000     18.229623   -3.277536   65.128417   48.219668   16.238315
# 100.0000     2.414573    0.036315    7.689592    5.786517    2.488549
# 1000.0000    0.249289    0.008728    0.783880    0.590946    0.260657
# 10000.0000   0.025010    0.000926    0.078541    0.059221    0.026188
#
#                     s2          s3          s4          s5          s6
# alpha
# 0.0000      518.062277  163.419983  275.317902  736.198859   48.670657
# ...

# %%
alphas = [0,0.0001,0.0005,0.001,0.005,0.1,0.5,1,5,10]

coefs = []

for i in alphas:
    reg = Ridge(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
input_array = np.array(coefs).T
plt.figure(figsize=(15,8))
plt.plot(alphas,np.zeros(len(alphas)),color='black',linewidth=5)
for i in range(input_array.shape[0]):
    plt.plot(alphas,input_array[i],label=data.feature_names[i])
plt.legend()
plt.show()

# %% [markdown]
# # 3. impact on bias and varience

# %%
m = 100
X = 5 * np.random.rand(m, 1) - 2
y = 0.7 * X ** 2 - 2 * X + 3 + np.random.randn(m, 1)

plt.scatter(X, y)
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(X.reshape(100,1),y.reshape(100),test_size=0.2,random_state=2)
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=15)

X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
from mlxtend.evaluate import bias_variance_decomp

alphas = np.linspace(0,30,100)

loss = []
bias = []
variance = []

for i in alphas:
    reg = Ridge(alpha=i)
    avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        reg, X_train, y_train, X_test, y_test, 
        loss='mse',
        random_seed=123)
    loss.append(avg_expected_loss)
    bias.append(avg_bias)
    variance.append(avg_var)

# %%
plt.plot(alphas,loss,label='loss')
plt.plot(alphas,bias,label='Bias')
plt.plot(alphas,variance,label='Variance')
plt.ylim(0,5)
plt.xlabel('Alpha')
plt.legend()
plt.show()

# %% [markdown]
# # 4. Effect of Regularization on Loss Function

# %%
from sklearn.datasets import make_regression

X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

plt.scatter(X,y)

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X,y)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
def cal_loss(m,alpha):
    return np.sum((y - m*X.ravel() + 2.29)**2) + alpha*m*m

def predict(m):
    return m*X - 2.29

# %%
m = np.linspace(-45,100,100)
plt.figure(figsize=(4,6))
for j in [0,10,20,30,40,50,100]:
    loss = []
    for i in range(m.shape[0]):
        loss_i = cal_loss(m[i],j)
        loss.append(loss_i)
    plt.plot(m,loss,label='alpha = {}'.format(j))
plt.legend()
plt.xlabel('m')
plt.ylabel('Loss')
plt.show()
